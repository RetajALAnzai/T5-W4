# %% [markdown]
# # Artificial Neural Networks for Binary Classification Exercise
#
# In this notebook we will build an ANN to predict whether customers will churn (indicated by the column `Churn`).
#
#
# ## Dataset
# - **Source**: [Kaggle](https://www.kaggle.com/datasets/ahmedgaitani/customer-churn-prediction-dataset/data).
# - **Variables of Interest**:
#   - `Churn`
# - As for the data card you should be able by now to figure the data out by your self :)
#
# ## Preprocessing Steps
#
# 1. **Dropping irrelevant columns**
# 2. **Encoding categorical variables**
# 3. **Data Splitting**
#
# ## Model Architecture
#
# - **Input Layer**: Please specify here (the trainee should this this)
# - **Hidden Layers**: Please specify here (the trainee should fill this)
# - **Output Layer**: Please specify here (the trainee should fill this)
#
# ## Training
#
# - **Optimizer**: Please specify here (the trainee should fill this)
# - **Loss Function**: Please specify here (the trainee should fill this)
# - **Metrics**: Please specify here (the trainee should fill this)
# - **Epochs**: Please specify here (the trainee should fill this)
# - **Batch Size**: Please specify here (the trainee should fill this)
# - **Validation Split**: Please specify here (the trainee should fill this)
#
# ## Evaluation
# - Please specify here (the trainee should fill this)
#
# If you need to change the steps or add more please do so and explain why!

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense

# %%
df=pd.read_csv("/content/Churn_Modelling_Exercise (1).csv")

# %% [markdown]
# # Load Data and EDA

# %%
df.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0001-XXXX    Male              0     Yes        Yes       5           No
# 1  0002-XXXX  Female              0      No         No      42          Yes
# 2  0003-XXXX    Male              0      No         No      61          Yes
# 3  0004-XXXX    Male              1      No        Yes      22          Yes
# 4  0005-XXXX    Male              1     Yes        Yes      21           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0               Yes              No                   No  ...
# 1  No phone service             DSL                  Yes  ...
# 2  No phone service              No                   No  ...
# 3                No              No  No internet service  ...
# 4                No             DSL                   No  ...
#
#       DeviceProtection TechSupport          StreamingTV      StreamingMovies  \
# 0                   No          No                   No  No internet service
# 1                   No          No  No internet service  No internet service
# 2                   No         Yes                  Yes                   No
# 3                  Yes          No  No internet service                  Yes
# 4  No internet service          No                   No  No internet service
#
#          Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# 0  Month-to-month              Yes       Credit card          27.43
# 1        Two year               No  Electronic check          38.28
# 2        One year               No     Bank transfer         106.44
# 3  Month-to-month               No  Electronic check          92.49
# 4        One year               No     Bank transfer          19.63
#
#    TotalCharges  Churn
# 0        137.15    Yes
# 1       1607.76    Yes
# 2       6492.84    Yes
# 3       2034.78     No
# 4        412.23    Yes
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 295  0296-XXXX  Female              1      No        Yes      61           No
# 296  0297-XXXX  Female              0      No         No      49          Yes
# 297  0298-XXXX    Male              0      No        Yes      71          Yes
# 298  0299-XXXX    Male              1     Yes        Yes       1          Yes
# 299  0300-XXXX  Female              1     Yes        Yes      13          Yes
#
#         MultipleLines InternetService       OnlineSecurity  ...  \
# 295               Yes             DSL                   No  ...
# 296  No phone service             DSL  No internet service  ...
# 297               Yes             DSL  No internet service  ...
# 298               Yes              No                  Yes  ...
# 299               Yes             DSL  No internet service  ...
#
#         DeviceProtection          TechSupport          StreamingTV  \
# 295                  Yes  No internet service                   No
# 296                  Yes  No internet service                  Yes
# 297                  Yes                  Yes                   No
# 298  No internet service  No internet service                  Yes
# 299                  Yes                   No  No internet service
#
#     StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 295              No        One year              Yes  Electronic check
# 296             Yes  Month-to-month              Yes      Mailed check
# 297             Yes        Two year               No      Mailed check
# 298             Yes        Two year               No       Credit card
# 299             Yes  Month-to-month               No  Electronic check
#
#     MonthlyCharges  TotalCharges  Churn
# 295          42.52       2593.72     No
# 296          22.31       1093.19    Yes
# 297          59.57       4229.47    Yes
# 298          31.32         31.32     No
# 299          20.50        266.50    Yes
#
# [5 rows x 21 columns]

# %%
df.sample(5)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 187  0188-XXXX    Male              1      No         No      27          Yes
# 266  0267-XXXX  Female              1     Yes        Yes      35           No
# 147  0148-XXXX    Male              1     Yes        Yes      11          Yes
# 35   0036-XXXX    Male              1      No        Yes       3          Yes
# 241  0242-XXXX    Male              1      No        Yes      29           No
#
#         MultipleLines InternetService       OnlineSecurity  ...  \
# 187  No phone service     Fiber optic  No internet service  ...
# 266                No     Fiber optic                   No  ...
# 147               Yes              No  No internet service  ...
# 35   No phone service              No                  Yes  ...
# 241                No             DSL                  Yes  ...
#
#         DeviceProtection          TechSupport          StreamingTV  \
# 187  No internet service                  Yes  No internet service
# 266                   No                   No                   No
# 147                  Yes  No internet service                   No
# 35                   Yes                   No  No internet service
# 241                   No  No internet service                  Yes
#
#     StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 187              No  Month-to-month               No     Bank transfer
# 266             Yes  Month-to-month              Yes       Credit card
# 147              No  Month-to-month              Yes  Electronic check
# 35              Yes        Two year               No     Bank transfer
# 241             Yes        One year               No       Credit card
#
#     MonthlyCharges  TotalCharges  Churn
# 187          61.81       1668.87    Yes
# 266          88.49       3097.15    Yes
# 147          38.78        426.58    Yes
# 35           97.38        292.14     No
# 241          37.14       1077.06    Yes
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        300 non-null    object
#  1   gender            300 non-null    object
#  2   SeniorCitizen     300 non-null    int64
#  3   Partner           300 non-null    object
#  4   Dependents        300 non-null    object
#  5   tenure            300 non-null    int64
#  6   PhoneService      300 non-null    object
#  7   MultipleLines     300 non-null    object
#  8   InternetService   300 non-null    object
#  9   OnlineSecurity    300 non-null    object
#  10  OnlineBackup      300 non-null    object
#  11  DeviceProtection  300 non-null    object
#  12  TechSupport       300 non-null    object
#  13  StreamingTV       300 non-null    object
#  14  StreamingMovies   300 non-null    object
#  15  Contract          300 non-null    object
#  16  PaperlessBilling  300 non-null    object
#  17  PaymentMethod     300 non-null    object
#  18  MonthlyCharges    300 non-null    float64
#  19  TotalCharges      300 non-null    float64
#  20  Churn             300 non-null    object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 49.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Drop unnecessary columns

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.drop(columns=["TotalCharges"],inplace=True)

# %% [markdown]
# ### One-hot-encoder and Label-encoder

# %%
encode_cols=["gender","Partner","Dependents","PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","Contract","PaperlessBilling","PaymentMethod"]
ohe_encode = OneHotEncoder(sparse_output=False)

one_hot_encoded = pd.DataFrame(ohe_encode.fit_transform(df[encode_cols]))

one_hot_df = pd.DataFrame(one_hot_encoded, columns=ohe_encode.get_feature_names_out(encode_cols))
df = pd.concat([df, one_hot_encoded], axis=1)

df_encoded = df

encoding_columns = encode_cols

df_encoded = df_encoded.drop(encoding_columns, axis=1)
df = df_encoded

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        label_encoder = LabelEncoder()
        df[column] = label_encoder.fit_transform(df[column])

# %% [markdown]
# ## Selecting Features && Train Test Split

# %% [markdown]
# ### Selecting Features

# %%
x=df.drop(columns=["Churn"])
y=df["Churn"]

# %% [markdown]
# ### Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
for column in x_train.columns:
    if x_train[column].dtype == 'object':
        label_encoder = LabelEncoder()
        x_train[column] = label_encoder.fit_transform(x_train[column])

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Creating the sequential model

# %%
model= Sequential()

# %% [markdown]
# ### Adding the input layer

# %%
model.add(tf.keras.layers.Dense(units=6,activation="relu"))

# %% [markdown]
# ### Adding the hidden layers

# %%
model.add(Dense(units=6, activation='relu'))
model.add(Dense(units=6, activation='relu'))
model.add(Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the output layer

# %%
model.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Display model summary

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Fitting the model

# %%
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.5634 - loss: 6.5935 - val_accuracy: 0.4167 - val_loss: 7.7128
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5524 - loss: 5.7909 - val_accuracy: 0.4167 - val_loss: 6.4652
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5624 - loss: 5.1568 - val_accuracy: 0.4167 - val_loss: 5.3042
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5708 - loss: 3.7373 - val_accuracy: 0.4167 - val_loss: 4.2362
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5312 - loss: 3.2349 - val_accuracy: 0.4167 - val_loss: 3.2180
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5634 - loss: 2.1621 - val_accuracy: 0.3750 - val_loss: 2.2795
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5185 - loss: 1.8824 - val_accuracy: 0.3750 - val_loss: 1.4707
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5261 - loss: 1.2750 - val_accuracy: 0.3958 - val_loss: 1.1326
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6080 - loss: 0.7815 - val_accuracy: 0.3750 - val_loss: 0.9451
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5763 - loss: 0.7344 - val_accuracy: 0.4375 - val_loss: 0.8158
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5103 - loss: 0.7337 - val_accuracy: 0.4792 - val_loss: 0.7440
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5932 - loss: 0.6688 - val_accuracy: 0.5208 - val_loss: 0.7217
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5601 - loss: 0.6861 - val_accuracy: 0.5208 - val_loss: 0.7157
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5439 - loss: 0.6855 - val_accuracy: 0.5000 - val_loss: 0.7156
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5708 - loss: 0.6861 - val_accuracy: 0.4583 - val_loss: 0.7205
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5500 - loss: 0.6851 - val_accuracy: 0.5625 - val_loss: 0.7262
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5669 - loss: 0.6876 - val_accuracy: 0.5208 - val_loss: 0.7325
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5607 - loss: 0.6863 - val_accuracy: 0.5000 - val_loss: 0.7373
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5466 - loss: 0.6877 - val_accuracy: 0.5000 - val_loss: 0.7380
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6365 - loss: 0.6681 - val_accuracy: 0.5000 - val_loss: 0.7400
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5773 - loss: 0.6799 - val_accuracy: 0.5000 - val_loss: 0.7375
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5807 - loss: 0.6731 - val_accuracy: 0.5000 - val_loss: 0.7363
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5918 - loss: 0.6723 - val_accuracy: 0.5000 - val_loss: 0.7351
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5717 - loss: 0.6879 - val_accuracy: 0.5208 - val_loss: 0.7333
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5862 - loss: 0.6719 - val_accuracy: 0.5000 - val_loss: 0.7349
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6178 - loss: 0.6700 - val_accuracy: 0.5000 - val_loss: 0.7372
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5856 - loss: 0.6729 - val_accuracy: 0.5000 - val_loss: 0.7378
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5978 - loss: 0.6670 - val_accuracy: 0.5000 - val_loss: 0.7388
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5871 - loss: 0.6627 - val_accuracy: 0.5000 - val_loss: 0.7384
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5832 - loss: 0.6741 - val_accuracy: 0.4792 - val_loss: 0.7371
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5393 - loss: 0.6931 - val_accuracy: 0.5208 - val_loss: 0.7356
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5662 - loss: 0.6780 - val_accuracy: 0.4792 - val_loss: 0.7387
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5765 - loss: 0.6777 - val_accuracy: 0.4792 - val_loss: 0.7393
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5940 - loss: 0.6718 - val_accuracy: 0.4792 - val_loss: 0.7406
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5924 - loss: 0.6719 - val_accuracy: 0.4792 - val_loss: 0.7398
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5765 - loss: 0.6707 - val_accuracy: 0.4792 - val_loss: 0.7382
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5949 - loss: 0.6583 - val_accuracy: 0.4583 - val_loss: 0.7385
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5649 - loss: 0.6717 - val_accuracy: 0.4792 - val_loss: 0.7369
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6370 - loss: 0.6578 - val_accuracy: 0.4583 - val_loss: 0.7388
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5906 - loss: 0.6683 - val_accuracy: 0.4792 - val_loss: 0.7354
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6378 - loss: 0.6587 - val_accuracy: 0.4792 - val_loss: 0.7333
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5537 - loss: 0.6816 - val_accuracy: 0.5000 - val_loss: 0.7304
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5794 - loss: 0.6621 - val_accuracy: 0.4792 - val_loss: 0.7324
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5933 - loss: 0.6710 - val_accuracy: 0.4792 - val_loss: 0.7328
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5987 - loss: 0.6726 - val_accuracy: 0.4792 - val_loss: 0.7328
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5715 - loss: 0.6701 - val_accuracy: 0.4792 - val_loss: 0.7329
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6035 - loss: 0.6607 - val_accuracy: 0.4583 - val_loss: 0.7347
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6092 - loss: 0.6567 - val_accuracy: 0.4792 - val_loss: 0.7319
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5752 - loss: 0.6742 - val_accuracy: 0.5000 - val_loss: 0.7283
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5777 - loss: 0.6674 - val_accuracy: 0.5000 - val_loss: 0.7279
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5958 - loss: 0.6656 - val_accuracy: 0.4792 - val_loss: 0.7300
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5676 - loss: 0.6710 - val_accuracy: 0.4792 - val_loss: 0.7290
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5782 - loss: 0.6659 - val_accuracy: 0.4792 - val_loss: 0.7300
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6356 - loss: 0.6530 - val_accuracy: 0.4583 - val_loss: 0.7336
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5642 - loss: 0.6752 - val_accuracy: 0.4792 - val_loss: 0.7289
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5542 - loss: 0.6743 - val_accuracy: 0.5208 - val_loss: 0.7241
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6084 - loss: 0.6499 - val_accuracy: 0.5208 - val_loss: 0.7249
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5560 - loss: 0.6670 - val_accuracy: 0.5208 - val_loss: 0.7259
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5904 - loss: 0.6645 - val_accuracy: 0.5208 - val_loss: 0.7254
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5786 - loss: 0.6510 - val_accuracy: 0.4583 - val_loss: 0.7305
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5948 - loss: 0.6466 - val_accuracy: 0.4792 - val_loss: 0.7322
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5863 - loss: 0.6675 - val_accuracy: 0.4792 - val_loss: 0.7277
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5530 - loss: 0.6713 - val_accuracy: 0.5417 - val_loss: 0.7226
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5622 - loss: 0.6684 - val_accuracy: 0.5417 - val_loss: 0.7237
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5792 - loss: 0.6555 - val_accuracy: 0.5417 - val_loss: 0.7249
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5869 - loss: 0.6611 - val_accuracy: 0.5000 - val_loss: 0.7272
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6022 - loss: 0.6561 - val_accuracy: 0.4792 - val_loss: 0.7294
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5452 - loss: 0.6722 - val_accuracy: 0.5000 - val_loss: 0.7271
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5629 - loss: 0.6670 - val_accuracy: 0.4792 - val_loss: 0.7298
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6039 - loss: 0.6596 - val_accuracy: 0.5000 - val_loss: 0.7295
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5890 - loss: 0.6560 - val_accuracy: 0.4792 - val_loss: 0.7305
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5658 - loss: 0.6665 - val_accuracy: 0.5417 - val_loss: 0.7261
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5866 - loss: 0.6562 - val_accuracy: 0.5417 - val_loss: 0.7245
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5883 - loss: 0.6569 - val_accuracy: 0.5417 - val_loss: 0.7242
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5906 - loss: 0.6578 - val_accuracy: 0.5000 - val_loss: 0.7298
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5934 - loss: 0.6571 - val_accuracy: 0.4792 - val_loss: 0.7329
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6103 - loss: 0.6445 - val_accuracy: 0.4792 - val_loss: 0.7348
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5856 - loss: 0.6684 - val_accuracy: 0.5000 - val_loss: 0.7278
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5760 - loss: 0.6705 - val_accuracy: 0.5417 - val_loss: 0.7234
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5714 - loss: 0.6559 - val_accuracy: 0.5417 - val_loss: 0.7242
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5902 - loss: 0.6590 - val_accuracy: 0.4792 - val_loss: 0.7295
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6193 - loss: 0.6474 - val_accuracy: 0.4792 - val_loss: 0.7324
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6109 - loss: 0.6524 - val_accuracy: 0.4792 - val_loss: 0.7307
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5937 - loss: 0.6576 - val_accuracy: 0.4792 - val_loss: 0.7301
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5889 - loss: 0.6574 - val_accuracy: 0.5000 - val_loss: 0.7287
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5711 - loss: 0.6667 - val_accuracy: 0.5417 - val_loss: 0.7263
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6199 - loss: 0.6487 - val_accuracy: 0.5000 - val_loss: 0.7299
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5916 - loss: 0.6522 - val_accuracy: 0.5208 - val_loss: 0.7281
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6232 - loss: 0.6464 - val_accuracy: 0.5417 - val_loss: 0.7262
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5821 - loss: 0.6684 - val_accuracy: 0.5417 - val_loss: 0.7239
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6027 - loss: 0.6606 - val_accuracy: 0.5417 - val_loss: 0.7258
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6411 - loss: 0.6391 - val_accuracy: 0.4792 - val_loss: 0.7308
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6121 - loss: 0.6472 - val_accuracy: 0.4792 - val_loss: 0.7317
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6484 - loss: 0.6292 - val_accuracy: 0.4792 - val_loss: 0.7322
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6144 - loss: 0.6485 - val_accuracy: 0.5417 - val_loss: 0.7262
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6319 - loss: 0.6542 - val_accuracy: 0.5417 - val_loss: 0.7267
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5968 - loss: 0.6530 - val_accuracy: 0.5417 - val_loss: 0.7264
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6139 - loss: 0.6489 - val_accuracy: 0.5417 - val_loss: 0.7275
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6010 - loss: 0.6491 - val_accuracy: 0.5417 - val_loss: 0.7275
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5593 - loss: 0.6771 - val_accuracy: 0.5417 - val_loss: 0.7253

# %% [markdown]
# ## Evaluating the model

# %%
model.evaluate(x_test,y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5764 - loss: 0.7338
# [0.7340811491012573, 0.5833333134651184]
